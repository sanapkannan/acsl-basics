# %%
sentence="My grandma's name is Viji"
print(sentence)
# Out:
# My grandma's name is Viji

# %%
dhev, sana, prasanna= 13, 10, 42
print(dhev)
print(sana)
print(prasanna)
# Out:
# 13
# 10
# 42

# %%
sana=dhev=prasanna=32
print(sana)
print(dhev)
print(prasanna)
# Out:
# 32
# 32
# 32

# %%
name, age= "sana", 10
print(name)
print(age)
# Out:
# sana
# 10

# %%
age1=10
age2=13
print(age1%age2)
# Out:
# 10

# %%
first_name = "Sana"
last_name = "Kannan"
print(first_name + " " + last_name)
# Out:
# Sana Kannan

# %%
sent="Sana was swimming wth her BFFs!"
print(sent[0:4])
# Out:
# Sana

# %%
n = 1
n = n+1
print('Simple expression value is', n)
# Out:
# Simple expression value is 2

# %%
j = 2
j +=2
print('Additional Assignment value is', j)

k = 2
k -=2
print('Subtraction Assignment value is', k)

l = 2
l *=2
print('Multiplication Assignment value is',l)

m = 2
m /=2
print('Division Assignment value is', m)
# Out:
# Additional Assignment value is 4
# Subtraction Assignment value is 0
# Multiplication Assignment value is 4
# Division Assignment value is 1.0

# %%
user_age = 10

if (user_age <= 12):
    print('User age is 12 or younger')
# Out:
# User age is 12 or younger

# %%
i = 1
while i<=6:
    print(i)
    i += 1

print('Execution Completed!')
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# Execution Completed!

# %%
i = 0
while i<=6:
    print(i)
    i += 1
else:
    print('Else statement is executed at the end as mandatory')

print('Execution Completed!')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Else statement is executed at the end as mandatory
# Execution Completed!

# %%
triplequote = """ Welcome to Vinoth 
Rathinam Tutorials"""
print(triplequote)
# Out:
#  Welcome to Vinoth
# Rathinam Tutorials

# %%
myString = 'Python for Machine learning'
print(myString[11:18])
# Out:
# Machine

# %%
myString2 = 'Python for Automation'
print(myString2[-10:])
# Out:
# Automation

# %%
myString2 = 'Python for Automation'

print(myString2[-1])
print(myString2[-2])
print(myString2[-11])
print(myString2[7:])
# Out:
# n
# o
#
# for Automation

# %%
str1 = 'Python'
print(str1)
print('Memory location before update', id)
# Out:
# Python
# Memory location before update <built-in function id>

# %%
str1 ="Hey! It's Katseye."
print(str1)
print(str.casefold)
# Out:
# Hey! It's Katseye.
# <method 'casefold' of 'str' objects>

# %%
str2 = "Hey! It's Katseye"
print("Length of string is",len(str2))
# Out:
# Length of string is 17

# %%
str3 = "HEY! IT'S KATSEYE"
print(str3.lower())
# Out:
# hey! it's katseye

# %%
list1 = []
print(list1)

list2 = [10,20,30,40,50]
print(list2)

list3 = ("Python","Java","C" )
print(list3)
# Out:
# []
# [10, 20, 30, 40, 50]
# ('Python', 'Java', 'C')

# %%
list2 = [10,20,30,40,50]
print(list2[2])
# Out:
# 30

# %%
list1 =['Sana', 'Dhev']
list2 =['Chitra','Vijayalakshmi','Selvaraj']
finallist = list1 + list2
print(list1)
print(list2)
print(finallist)
# Out:
# ['Sana', 'Dhev']
# ['Chitra', 'Vijayalakshmi', 'Selvaraj']
# ['Sana', 'Dhev', 'Chitra', 'Vijayalakshmi', 'Selvaraj']

# %%
tuple = ((15,25), ("Python","Data Science"))
print("Nested Tuples", tuple)
# Out:
# Nested Tuples ((15, 25), ('Python', 'Data Science'))

# %%
name = ('Sana')
print(type(name))
name2 = ('Pippa',)
print(type(name2))
# Out:
# <class 'str'>
# <class 'tuple'>

# %%
my_dict = {}
print('Empty dictionary is created', my_dict)

colors = {1:'red', 2:'green', 3:'Yellow'}
print(colors)
# Out:
# Empty dictionary is created {}
# {1: 'red', 2: 'green', 3: 'Yellow'}

# %%
list = ['red', 'orange', 'blue', 1, 2, 3]
list
# Out:
# ['red', 'orange', 'blue', 1, 2, 3]

# %%
dic = {'1' : 'red', '2' : 'orange'}
dic
# Out:
# {'1': 'red', '2': 'orange'}

# %%
dic.keys()
# Out:
# dict_keys(['1', '2'])

# %%
dic.values()
# Out:
# dict_values(['red', 'orange'])

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
def welcome_user_one():
    print('Hello user one')
welcome_user_one()
# Out:
# Hello user one

# %%
def Welcome_user_two():
    print('Hello user two')
    welcome_user_one()
Welcome_user_two()
# Out:
# Hello user two
# Hello user one

# %%
def factorial(num):
    return 1 if num == 1 else (num * factorial(num-1))
factorial(5)
# Out:
# 120

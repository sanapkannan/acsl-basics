# %%
# Input : solve("A3B", 2) Output: "CD"
# Input : solve("XYZ", 3) Output: "ABC"

# %%
# input_string:"XYZ"
# alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
# output = ""
# for c in input_string:
#     if c in alphabet:
#       idx = (alphabet.index(c) + shift_amount) % 26
#       output += alphabet[idx]



# print(output)

# %%
def solve(input_string, shift_amount):
    output = ""
    for c in input_string:
        if c in alphabet:
          idx = (alphabet.index(c) + shift_amount) % 26
          output += alphabet[idx]
    return output

# %%
print(solve("A3B", 2))
print(solve("XYZ", 3))
# Out:
# CD
# ABC

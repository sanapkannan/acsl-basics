# %%
s1= 'Sana'
s2= 'Pippa'
print(s1)
print(s2)
# Out:
# Sana
# Pippa

# %%
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
rollnumber = 12345
name = "Sana"
marks = 80.5
print(rollnumber,name,marks)
# Out:
# 12345 Sana 80.5

# %%
A,B,C,D = 10,20,30,40
print(A,B,C,D,)
# Out:
# 10 20 30 40

# %%
NAME,ROLLNUMBER,MARKS = 'Sana', 12345,80.75
print(NAME,ROLLNUMBER,MARKS)
# Out:
# Sana 12345 80.75

# %%
i = 50
f = 3.14
x = 2 + 3j
print(i,f,x)
# Out:
# 50 3.14 (2+3j)

# %%
x = 20
y = 5

print('Addition of x + y=', x+y)

print('Subtraction of x - y=', x-y)

print('Multiplication of x * y=', x*y)
# Out:
# Addition of x + y= 25
# Subtraction of x - y= 15
# Multiplication of x * y= 100

# %%
j= 3 * 1.5
print(j)
print(type(j))
# Out:
# 4.5
# <class 'float'>

# %%
x = 10
y = 3
print('Float Division of x/y=', x/y)
print('Intiger Divisionn of x//y=', x//y)
print('Intiger Division of Negative Numbers =',-10//3)
# Out:
# Float Division of x/y= 3.3333333333333335
# Intiger Divisionn of x//y= 3
# Intiger Division of Negative Numbers = -4

# %%
x = 5
y = 2
print('Modulus of x%y=', x%y)
# Out:
# Modulus of x%y= 1

# %%
a = 20
b = 10
print('{} > {} is'.format(a,b),a>b)
# Out:
# 20 > 10 is True

# %%
a = True
b = False
print('a and b is', a and b)
# Out:
# a and b is False

# %%
a = True
b = False

x = 50
y = 100

print('a and b is', a and b)
print(x==y and x<y)
# Out:
# a and b is False
# False

# %%
a = True
b = False

x = 50
y = 100

print('a and b is', a and b)
print(x==y and x<y)

print('*******************')

print('a and b is', a or b)
print(x==y and x<y)

print('*******************')
# Out:
# a and b is False
# False
# *******************
# a and b is True
# False
# *******************

# %%
num = 5
if num > 0:
    print('Positive number')
elif num == 0:
    print('Number is zero')
    
else:
    print('Negative number')
# Out:
# Positive number

# %%
num = 2000
if 9 < num < 99:
    print('Two digit number')
elif 99 < num < 999:
    print('Three digit number')
elif 999 < num < 9999:
    print('Four digit number')
else:
    print('Number is not in the mentioned range')
# Out:
# Four digit number
